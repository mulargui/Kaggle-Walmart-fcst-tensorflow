# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 0.24.2
# 1.16.4

# %%
#load data
dffeatures=pd.read_csv('https://raw.githubusercontent.com/mulargui/Kaggle-Walmart-fcst-tensorflow/master/kaggle/features.csv')

#print(dffeatures.head())
print(dffeatures.shape[0])
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# 421570
# 115064
# 8190

# %%
#nans per feature
print(dffeatures.isnull().sum(axis = 0))
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
#do we have rows with all 0's?
print(dftrain.loc[(dftrain['Store2'] == 0.0) & (dftrain['Dept2'] == 0.0) & (dftrain['Year'] == 0.0) & (dftrain['Seasonality'] == 0.0)])
print(dftest.loc[(dftest['Store2'] == 0.0) & (dftest['Dept2'] == 0.0) & (dftest['Year'] == 0.0)])
# Out:
# Empty DataFrame
# Columns: [Store, Dept, Date, Seasonality, Year, Size, Type_A, Type_B, Type_C, Temperature, Fuel_Price, IsHoliday_False, IsHoliday_True, Store2, Dept2, Weekly_Sales]
# Index: []
# Empty DataFrame
# Columns: [Store, Dept, Date, Seasonality, Year, Size, Type_A, Type_B, Type_C, Temperature, Fuel_Price, IsHoliday_False, IsHoliday_True, Store2, Dept2]
# Index: []

# %%
#min, max and mean per column
print(dffeatures.agg([min, max]))
# Out:
#      Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# min      1  2010-02-05        -7.29       2.472   -2781.45    -265.76
# max     45  2013-07-26       101.95       4.468  103184.98  104519.54
#
#      MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# min    -179.26       0.22    -185.17  126.064000         3.684      False
# max  149483.31   67474.85  771448.10  228.976456        14.313       True

# %%
#rows with 0
print(dffeatures.loc[(dffeatures['Temperature'] == 0.0)])
print(dffeatures.loc[(dffeatures['MarkDown1'] == 0.0)])
print(dffeatures.loc[(dffeatures['MarkDown2'] == 0.0)])
print(dffeatures.loc[(dffeatures['MarkDown3'] == 0.0)])
print(dffeatures.loc[(dffeatures['MarkDown5'] == 0.0)])
# Out:
# Empty DataFrame
# Columns: [Store, Date, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment, IsHoliday]
# Index: []
# Empty DataFrame
# Columns: [Store, Date, Temperature, Fuel_Price, MarkDown1, MarkDown2, MarkDown3, MarkDown4, MarkDown5, CPI, Unemployment, IsHoliday]
# Index: []
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 1770     10  2012-08-17        88.83       4.002    4407.90        0.0
# 4503     25  2012-09-07        72.79       3.911   15308.07        0.0
# 5190     29  2011-11-25        46.28       3.536     122.33        0.0
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 1770       7.20    3037.56    3717.52  130.790968         7.170      False
# 4503      22.06    5643.24    1903.09  215.218957         7.280       True
# 5190   47289.47       4.00    1179.49  136.478800         9.357       True
# ...
